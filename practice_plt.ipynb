# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
def plot_2d_normal_dist(mean, cov, plt, nsamples = 200):
    """
    """
    
    from scipy.stats import multivariate_normal
    import numpy as np
    import itertools as IT
    
    mean = np.array(mean)
    cov = np.array(cov)
    rv = multivariate_normal(mean, cov)

    x = np.linspace(-4, 4, nsamples)
    y = np.linspace(-4, 4, nsamples)
    state = np.array(list(IT.product(x, y)))
    pdf = rv.pdf(state.reshape(nsamples, nsamples, -1))
    Z = pdf
    plt.pcolor(X, Y, Z, cmap='Blues')
#     plt.colorbar()
    return plt

# %%
mean = np.array([0,0])
cov = np.array([[2,2],[2,5]])
plot_2d_normal_dist(mean, cov, plt)
plt.show()

# %%
x = np.arange(0, 4, 0.1)
fig1 = plt.figure(1)
for i in range(4):
    ax = fig1.add_subplot(2,2,i+1)
    plot_2d_normal_dist(mean, cov, ax)
